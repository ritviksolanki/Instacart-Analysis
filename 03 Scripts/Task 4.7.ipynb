# %% [markdown]
# # Task 4.7 Deriving New Variables

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
#Importing Dataframes
df_ords_prods_merged=pd.read_pickle(r'/Users/ritviksolanki/Desktop/Instacart Basket Analysis /02 Data/Prepared Data/orders_products_merged.pkl')

# %%
#Defining a path
path=r'/Users/ritviksolanki/Desktop/Instacart Basket Analysis /02 Data/Prepared Data'

# %%
#Create a subset data of the first million rows
df=df_ords_prods_merged[:1000000]

# %%
#Check shape
df.shape
# Out:
# (1000000, 14)

# %% [markdown]
# # Using if then statements

# %%
#Define price label function
def price_label(row):
    if row['prices']<=5: return 'Low-Range Product'
    elif (row['prices']>5) and (row['prices']<=15): return 'Mid-range product'
    elif row['prices']>15: return 'High end product'
    else: return 'Not enough Data'

# %%
#Apply Price label to dataframe 
df['price_label']=df.apply(price_label,axis=1)
# Out:
# /var/folders/s_/mbly3n7n6758gnyrz7sphvq80000gn/T/ipykernel_45927/1651878715.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_label']=df.apply(price_label,axis=1)

# %%
#Count how many of each price range
df['price_label'].value_counts(dropna=False)
# Out:
# Mid-range product    756450
# Low-Range Product    243550
# Name: price_label, dtype: int64

# %% [markdown]
# # If Statements with Loc() function

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/s_/mbly3n7n6758gnyrz7sphvq80000gn/T/ipykernel_45927/1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# Check value counts
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %%
# Repeat process on entire dataframe
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, ' price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df_ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] < 5, 'price_range_loc'] = "Low-range product"

# %%
# Check value counts
df_ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    21890146
# Low-range product     9900480
# NaN                    643586
# Name: price_range_loc, dtype: int64

# %% [markdown]
# If Statements for Loops

# %%
# Create new column in dataframe
df_ords_prods_merged['order_dow'].value_counts(dropna = False)
# Out:
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: order_dow, dtype: int64

# %%
# Set loop
result = []

for value in df_ords_prods_merged["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Add result to dataframe
df_ords_prods_merged['busiest_day'] = result

# %%
# Check value counts
df_ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22437387
# Busiest day        6209632
# Least busy         3787193
# Name: busiest_day, dtype: int64

# %% [markdown]
# # Exercise 4.7 Task 2

# %%
# Create new if-statement for-loop for new requirements
result_v2 = []

for value in df_ords_prods_merged["order_dow"]:
  if value == 0 or value == 1:
    result_v2.append("Busiest days")
  elif value == 4 or value == 3:
    result_v2.append("Least busy days")
  else:
    result_v2.append("Regularly busy")

# %%
# Add result to dataframe in new column
df_ords_prods_merged['busiest_days'] = result_v2

# %%
# Check
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge  price_range_loc  \
# 0         Soda        77              7     9.0   both              NaN
# ...

# %% [markdown]
# # Task 4.7 Step 3 Busiet_days column

# %%
df_ords_prods_merged['busiest_days'].value_counts(dropna=False)
# Out:
# Regularly busy     12927461
# Busiest days       11875462
# Least busy days     7631289
# Name: busiest_days, dtype: int64

# %% [markdown]
# These counts seem accurate

# %% [markdown]
# # Task 4.7 Step 4

# %%
# Check frequency of values in the "order_hour_of_day" column 
df_ords_prods_merged['order_hour_of_day'].value_counts()
# Out:
# 10    2764390
# 11    2738585
# 14    2691563
# 15    2664522
# 13    2663272
# 12    2620800
# 16    2537469
# 9     2456661
# 17    2089452
# 8     1719952
# 18    1637922
# 19    1259382
# 20     977017
# 7      891928
# 21     796362
# 22     634737
# 23     402612
# 6      290770
# 0      218942
# 1      115786
# 5       88057
# 2       69431
# 4       53283
# 3       51317
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# If the client wants order hour of the day broken into categories, then we can group Most orders=10,11,12,13,14,14,16,9; Average Orders=17,8,18,19,20,7,21,22; Fewer Orders= 0,1,2,3,4,5,6,23

# %%
# Create a for-loop if statement using the above breakdown
hour_of_day = []

for value in df_ords_prods_merged["order_hour_of_day"]:
  if value in [10, 11, 14, 15, 13, 12, 16, 9]:
    hour_of_day.append("Most orders")
  elif value in [23, 6, 0, 1, 5, 2, 4, 3]:
    hour_of_day.append("Fewest orders")
  else:
    hour_of_day.append("Average orders")

# %%
# Add result to dataframe as "busiest_period_of_day" column
df_ords_prods_merged['busiest_period_of_day'] = hour_of_day

# %%
# Check
df_ords_prods_merged[['order_hour_of_day', 'busiest_period_of_day']].head(10)
# Out:
#    order_hour_of_day busiest_period_of_day
# 0                  8        Average orders
# 1                  7        Average orders
# 2                 12           Most orders
# 3                  7        Average orders
# 4                 15           Most orders
# 5                  7        Average orders
# 6                  9           Most orders
# 7                 14           Most orders
# 8                 16           Most orders
# 9                  8        Average orders

# %% [markdown]
# # Task 4.7 Step 5

# %%
df_ords_prods_merged['busiest_period_of_day'].value_counts()
# Out:
# Most orders       21137262
# Average orders    10006752
# Fewest orders      1290198
# Name: busiest_period_of_day, dtype: int64

# %%
#Export pickle as file 
df_ords_prods_merged.to_pickle(os.path.join(path, 'orders_products_merged_updated.pkl'))
